# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

import yfinance as yf
import time
import datetime as dt

# %% [markdown]
# # 01. Loading the stock

# %% [markdown]
# * N_STEPS: number of days for window → `depth`/ `length` of input sequence which the neural network will process
# * LOOKUP_STEPS: array which includes the number and sequence of days for the prediction:
#     * array `[1, 2, 3]` represents a forecast for three days:
#         * 1: tomorrow
#         * 2: the day after tomorrow
#         * 3: the day after the second day
# * STOCK: ticker-symbol/unique code of letters assigned to a publicly traded company's stock (GOOGL the ticker on NASDAQ).

# %%
N_STEPS = 7
LOOKUP_STEPS = [1, 2, 3]
STOCK_g = 'GOOGL'
STOCK_a = 'AAPL'

date_now = time.strftime('%Y-%m-%d')
date_2years_ago = (dt.date.today() - dt.timedelta(days=730)).strftime('%Y-%m-%d')
date_3years_ago = (dt.date.today() - dt.timedelta(days=1095)).strftime('%Y-%m-%d')

print(date_now
     )
# Out:
# 2024-02-15

# %%
# loading the apple and google stocks
stock_google = yf.download(STOCK_g,
                           start=date_3years_ago,
                           end=date_now,
                           interval='1d')

stock_apple = yf.download(STOCK_a, 
                          start=date_2years_ago,
                          end=date_now,
                          interval='1d')

# remove ne unnecessary columns → only focus on 'Close' (displays the price on the closing market that day)
close_apple = stock_apple.drop(['Open', 'High', 'Low', 'Adj Close', 'Volume'], axis=1)

close_google = stock_google.drop(['Open', 'High', 'Low', 'Adj Close', 'Volume'], axis=1)

# reset the index and rename the 'Close' columns
close_apple = close_apple.reset_index()
close_apple.rename(columns={'Close':'Apple_close'}, 
                   inplace=True)

close_google = close_google.reset_index()
close_google.rename(columns={'Close':'Google_close'}, 
                    inplace=True)   # allows to apply to changes to the initial df

# print the resulting columns
print(close_apple.head(5))
print()
print(close_google.head(5))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#         Date  Apple_close
# 0 2022-02-15   172.789993
# 1 2022-02-16   172.550003
# 2 2022-02-17   168.880005
# 3 2022-02-18   167.300003
# 4 2022-02-22   164.320007
#
#         Date  Google_close
# 0 2021-02-16    105.535004
# 1 2021-02-17    105.931000
# 2 2021-02-18    105.290497
# 3 2021-02-19    104.440498
# 4 2021-02-22    102.712997

# %% [markdown]
# # 02. Displaying the data

# %%
plt.figure(figsize=(15, 5))
plt.plot(close_apple['Date'], close_apple['Apple_close'], color='blue', label='Apple')
plt.plot(close_google['Date'], close_google['Google_close'], color='red', label='Google')
plt.xlabel('days')
plt.ylabel('price')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # 03. Normalizing the Data

# %% [markdown]
# When working with multiple time series data, such as stock prices for different stocks, it's common practice to normalize each time series separately rather than together.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
close_apple['Apple_close'].shape
# Out:
# (502,)

# %%
def reshaper_2d(col):
    col = col.values.reshape((-1, 1))
    return col

# %% [markdown]
# for the `MinMaxScaler()` we need the a 2 dimensional array, therefore the shape needs first to be readjusted

# %%
scaler_apple = MinMaxScaler()
scaler_google = MinMaxScaler()

apple_np = reshaper_2d(close_apple['Apple_close'])
google_np = reshaper_2d(close_google['Google_close'])

close_apple_rescaled = close_apple.copy()
close_google_rescaled = close_google.copy()

close_apple_rescaled['Apple_close'] = scaler_apple.fit_transform(apple_np)
close_google_rescaled['Google_close'] = scaler_google.fit_transform(google_np)

# %%
plt.figure(figsize=(15, 5))
plt.plot(close_apple_rescaled['Date'], close_apple_rescaled['Apple_close'], color='blue', label='Apple')
plt.plot(close_google_rescaled['Date'], close_google_rescaled['Google_close'], color='red', label='Google')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # 04. Preparation of the data for the engine

# %% [markdown]
# In order to being able to train a model an stock prizes, we need to bring the data in an acceptable format:
# * 7 `Timesteps` → list of lists, where each sublist entails 7 censequtive stock prices (1 `Feature`)
# * for each sublist we need a `Label` (Future), in this case the prediction in #'LOOKUP_STEPS' days
#
# <img src="./data_preparation.png" width="500"/>

# %%
from collections import deque                             # double ended queue, elements can be added and removed efficiently form both ends

# %%
def PrepareData(initial_df, days):
    df = initial_df.copy()
    df['Future'] = df.iloc[:, 1].shift(-days)             # creates a new column & shifts the 'close'-column #'DAYS' rows up → at the bootom of the 'future'-column will be #'DAYS' NaNs
    last_sequence = np.array(df.iloc[:, 1].tail(days))       # returns the last #days from the 'close'-column
    df.dropna(inplace=True)                               # removes the last #days rows of the df
  
    sequence_data = list()
    sequences = deque(maxlen=N_STEPS)                     # deque-object is created with the maximum length of 7
                                                                # after it reaches its `maxlen` it removes it's 1. item and adds the new one at the 7. place

    for entry, target in zip(df.iloc[:, [1, 0]].values,  # selects the columns 'X_close' & 'Date'
                             df['Future'].values):
        sequences.append(entry)
        if len(sequences) == N_STEPS:                               # after 'seqnces' reached length of 7
            sequence_data.append([np.array(sequences), target])         # 'close' & 'date' (=sequnce) + target (=close #'DAYS' rows up) 

    # last sequence
    last_sequence = list([seq[0] for seq in sequences]) + list(last_sequence)   # selects all 'close' entries from 'sequences'-'entry'
    last_sequence = np.array(last_sequence).astype(np.float32)

    # construct the X's and Y's
    X = list()
    y = list()
    for seq, target in sequence_data:
        X.append(seq)             # 'df[['X_close'] + ['Date']]'
        y.append(target)          # 'Future'-values

    # convert to numpy arrays
    X = np.array(X)
    y = np.array(y)

    return df, last_sequence, X, y

# %% [markdown]
# * df['Date', 'X_close', 'Future']
# * last_sequence: 'Close_values' for the entries without the last #'DAYS' + entries  for the last #'DAYS'
# * X: list of lists containing 7 seqences (moving one at a time)
# * y: prdicted Value #'DAYS' days prior

# %% [markdown]
# # 05. CNN

# %%
def GetTrainedModel(X_train, y_train):
    model = tf.keras.Sequential([
          tf.keras.layers.LSTM(units=60,
                              return_sequences=True,
                              input_shape=(N_STEPS, 1)),     # 7 time steps (consequitive days), 1 feature (closing price)
          tf.keras.layers.Dropout(0.3),
          tf.keras.layers.LSTM(units=120, return_sequences=False),
          tf.keras.layers.Dropout(0.3),
          tf.keras.layers.Dense(units=20),
          tf.keras.layers.Dense(units=1)  
      ])

    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['acc'])

    model.fit(X_train, y_train,
              batch_size=8,
              epochs=80, 
              verbose=0)

    return model

# %% [markdown]
# <img src="./stock_3days.png" width="500"/>

# %%
# GET PREDICTIONS

def predict_future(df_name, scaler):
    predictions = []
    
    for step in LOOKUP_STEPS:
        df, last_sequence, X_train, y_train = PrepareData(df_name, step)
        X_train = X_train[:, :, 0].astype(np.float32).reshape(-1, 7, 1)

        model = GetTrainedModel(X_train, y_train)

        last_sequence = last_sequence[-N_STEPS:]     # takes the last seqence with #'N_STEPS' which will be used for a prediction #'LOOKUP_STEPS' from today
        last_sequence = last_sequence.reshape((-1, 1))  # shape: (7, 1)
        prediction = model.predict(last_sequence)
        predicted_price = scaler.inverse_transform(prediction)[0][0]

        predictions.append(round(float(predicted_price), 2))
        
    return predictions, df
        
predictions_apple, df_a = predict_future(close_apple_rescaled, scaler_apple)
predictions_google, df_g = predict_future(close_google_rescaled, scaler_google)
# Out:
# 2024-02-15 19:49:56.178434: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-15 19:49:56.179049: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Metal device set to: Apple M2
# 2024-02-15 19:49:56.619773: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2024-02-15 19:49:57.829056: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:49:57.979752: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:49:58.082219: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:49:58.303240: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:49:58.456231: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:Model was constructed with shape (None, 7, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 7, 1), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (None, 1, 1).
# 1/1 [==============================] - 0s 344ms/step
# 2024-02-15 19:51:04.883148: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:51:04.930334: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:51:04.967742: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:51:06.370964: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:51:06.515113: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:51:06.576488: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:51:06.727560: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:51:06.846523: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:Model was constructed with shape (None, 7, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 7, 1), dtype=tf.float32, name='lstm_2_input'), name='lstm_2_input', description="created by layer 'lstm_2_input'"), but it was called on an input with incompatible shape (None, 1, 1).
# 1/1 [==============================] - 0s 336ms/step
# 2024-02-15 19:52:13.460452: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:52:13.511555: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:52:13.548864: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:52:15.046191: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:52:15.216580: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:52:15.286159: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:52:15.417621: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:52:15.547247: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:Model was constructed with shape (None, 7, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 7, 1), dtype=tf.float32, name='lstm_4_input'), name='lstm_4_input', description="created by layer 'lstm_4_input'"), but it was called on an input with incompatible shape (None, 1, 1).
# 1/1 [==============================] - 0s 389ms/step
# 2024-02-15 19:53:22.509438: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:53:22.556699: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:53:22.596619: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:53:24.212601: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:53:24.358231: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:53:24.426001: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:53:24.565899: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:53:24.724109: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:Model was constructed with shape (None, 7, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 7, 1), dtype=tf.float32, name='lstm_6_input'), name='lstm_6_input', description="created by layer 'lstm_6_input'"), but it was called on an input with incompatible shape (None, 1, 1).
# 1/1 [==============================] - 0s 447ms/step
# 2024-02-15 19:55:04.699022: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:55:04.749701: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:55:04.785720: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:55:06.491079: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:55:06.644526: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:55:06.732854: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:55:06.877775: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:55:07.027272: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:Model was constructed with shape (None, 7, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 7, 1), dtype=tf.float32, name='lstm_8_input'), name='lstm_8_input', description="created by layer 'lstm_8_input'"), but it was called on an input with incompatible shape (None, 1, 1).
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x28e79f520> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 379ms/step
# 2024-02-15 19:56:50.226986: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:56:50.276125: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:56:50.316036: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:56:51.623239: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:56:51.792970: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:56:51.863176: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:56:52.019896: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:56:52.199635: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:Model was constructed with shape (None, 7, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 7, 1), dtype=tf.float32, name='lstm_10_input'), name='lstm_10_input', description="created by layer 'lstm_10_input'"), but it was called on an input with incompatible shape (None, 1, 1).
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x2bcfdcaf0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 671ms/step
# 2024-02-15 19:58:36.222998: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:58:36.273053: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2024-02-15 19:58:36.319785: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
today = dt.date.today()

# list with days from yesterday to after tomorrow
upcoming_days = [(today + dt.timedelta(days=i)) for i in range(-1, LOOKUP_STEPS[-1])]

# adding the yesterdays price on the closing market to the prediction lists
predictions_apple.insert(0, close_apple['Apple_close'].iloc[-1])
predictions_google.insert(0, close_google['Google_close'].iloc[-1])


plt.figure(figsize=(15, 5))
plt.plot(close_apple['Date'], close_apple['Apple_close'], color='blue', label='Apple')
plt.plot(upcoming_days, predictions_apple, color='orange', label='Apple pred.', linestyle='dashed')
plt.plot(close_google['Date'], close_google['Google_close'], color='red', label='Google')
plt.plot(upcoming_days, predictions_google, color='green', label='Google pred.', linestyle='dashed')
plt.xlabel('days')
plt.ylabel('price')
plt.legend(loc="lower right")
plt.show()
